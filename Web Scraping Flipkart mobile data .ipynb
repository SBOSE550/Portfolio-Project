# %% [markdown]
# # Importing library:

# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Difining funtion:

# %%
def get_Product_name(soup):
    try:
        Product_name = soup.find('span',attrs = {'class':'VU-ZEz'}).text.strip()
    except AttributeError:
        Product_name = ''
    return Product_name
def get_price(soup):
    try:
        price = soup.find('div',attrs = {'class':'Nx9bqj CxhGGd'}).text.strip()
    except AttributeError:
        price = ''
    return price
def get_rating(soup):
    try:
        rating = soup.find('div',attrs = {'class':'XQDdHH'}).text.strip()
    except AttributeError:
        rating = ''
    return rating
def get_Delivery_date(soup):
    try:
        Delivery_date = soup.find('span',attrs = {'class':'Y8v7Fl'}).text.strip()
    except AttributeError:
        Delivery_date = ''
    return Delivery_date
def get_num_of_rating(soup):
    try:
        num_of_rating = soup.find('div',attrs = {'class':'row j-aW8Z'}).text.strip()
    except AttributeError:
        num_of_rating = ''
    return num_of_rating

# %%
# Initialize an empty list to store all the product data
all_data = []
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36','Accept-Language':'en-Us,en;q=0.5'})
# Iterate over first 5  pages
for i in range(2, 7):
    # Construct the URL for the search page
    url = 'https://www.flipkart.com/search?q=phone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=' + str(i)
    
    # Send a GET request to the URL with custom headers
    page = requests.get(url, headers=HEADERS)
    
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Find all the links of the product pages on the search page
    links = soup.find_all('a', attrs={'class': 'CGtC98'})
    
    # Iterate over each product link
    for link in links:
        # Send a GET request to the product page
        new_page = requests.get('https://flipkart.com' + link.get('href'), headers=HEADERS)
        
        # Parse the HTML content of the product page using BeautifulSoup
        new_soup = BeautifulSoup(new_page.content, 'html.parser')
        
        # Initialize a dictionary to store product data
        product_data = {
            'Product_name': get_Product_name(new_soup),
            'price': get_price(new_soup),
            'rating': get_rating(new_soup),
            'Delivery_date': get_Delivery_date(new_soup),
            'num_of_rating': get_num_of_rating(new_soup)
        }
        
        # Extract specification data for the product
        table_data = new_soup.find('div', attrs={'class': '_1OjC5I'}).find_all('table', attrs={'class': '_0ZhAN9'})
        for table in table_data:
            column = [td.text.strip() for td in table.find_all('td', attrs={'class': '+fFi1w col col-3-12'})]
            row = [td.text.strip() for td in table.find_all('td', attrs={'class': 'Izz52n col col-9-12'})]
            product_data.update(dict(zip(column, row)))
        
        # Append the product data to the list of all_data
        all_data.append(product_data)

# Create a DataFrame from the collected product data
df = pd.DataFrame(all_data)
# extrating the data frame as CSV file.
df.to_csv('web scraping Flipkart mobile data.csv',header=True, index=False)

# %%
df.head()
# Out:
#                                         Product_name    price rating  \
# 0  MOTOROLA g24 Power (Glacier Blue, 128 GB)  (4 ...   ₹7,999    4.2
# 1     REDMI 13C (Stardust Black, 128 GB)  (4 GB RAM)   ₹7,699    4.3
# 2    REDMI 13C (Starshine Green, 128 GB)  (4 GB RAM)   ₹7,699    4.3
# 3         POCO C65 (Pastel Blue, 128 GB)  (4 GB RAM)   ₹6,799    4.2
# 4  Motorola Edge 50 Pro 5G with 68W Charger (Blac...  ₹30,999    4.4
#
#     Delivery_date     num_of_rating  \
# 0  10 May, Friday   6,972 Ratings &
# 1  10 May, Friday  12,122 Ratings &
# 2  10 May, Friday  12,122 Ratings &
# 3  10 May, Friday  13,648 Ratings &
# 4  10 May, Friday   6,073 Ratings &
#
#                                           In The Box Model Number  \
# 0  Handset, 33W TurboPower Charger, USB Type-C Ca...   PB1C0001IN
# 1  Handset, 10W Charger, USB Type-C Cable, Sim Ej...    MZB0FOPIN
# 2  Handset, 10W Charger, USB Type-C Cable, Sim Ej...    MZB0FW5IN
# 3  Handset, 10W Charger, USB Type-C Cable, Sim Ej...    MZB0G8NIN
# 4  Handset, 68W TurboPower Charger (Phone Capable...   PB3M0000IN
#
#        Model Name            Color  Browse Type  SIM Type Hybrid Sim Slot  \
# 0       g24 Power     Glacier Blue  Smartphones  Dual Sim              No
# 1             13C   Stardust Black  Smartphones  Dual Sim              No
# 2             13C  Starshine Green  Smartphones  Dual Sim              No
# 3             C65      Pastel Blue  Smartphones  Dual Sim              No
# 4  Edge 50 Pro 5G     Black Beauty  Smartphones  Dual Sim              No
#
#   Touchscreen OTG Compatible Quick Charging  \
# 0         Yes            Yes            Yes
# 1         Yes            Yes            Yes
# 2         Yes            Yes            Yes
# 3         Yes            Yes            Yes
# 4         Yes            Yes            Yes
#
#                                   Sound Enhancements          Display Size  \
# 0               Stereo speakers, Dolby Atmos Support   16.76 cm (6.6 inch)
# 1                                                NaN  17.12 cm (6.74 inch)
# 2                                                NaN  17.12 cm (6.74 inch)
# 3                                                NaN  17.12 cm (6.74 inch)
# 4  Dual Stereo Speakers, Tuning by Dolby Atmos, S...   17.02 cm (6.7 inch)
#
#            Resolution Resolution Type               GPU  \
# 0   1612 x 720 Pixels             HD+  Arm Mali-G52 MP2
# 1   1650 x 720 Pixels             HD+  Arm Mali-G52 MC2
# 2   1650 x 720 Pixels             HD+  Arm Mali-G52 MC2
# 3   1650 x 720 Pixels             HD+  Arm Mali-G52 MC2
# 4  2712 x 1220 Pixels             NaN               NaN
#
#                                         Display Type  \
# 0                                HD+ IPS LCD Display
# 1                                   HD+ 90Hz Display
# 2                                   HD+ 90Hz Display
# 3  HD+ 90Hz Display with Corning Gorilla Glass 3 ...
# 4                              Super HD 1.5K Display
#
#                               Other Display Features Operating System  \
# 0                                  90Hz Refresh Rate       Android 14
# 1                 Corning Gorilla Glass 3 Protection       Android 13
# 2                 Corning Gorilla Glass 3 Protection       Android 13
# 3                                                NaN       Android 13
# 4  Screen-to-Body Ratio: 90.75%, pOLED, HDR10+, 1...       Android 14
#
#   Processor Brand           Processor Type Processor Core Primary Clock Speed  \
# 0        Mediatek                Helio G85      Octa Core               2 GHz
# 1        Mediatek                Helio G85      Octa Core               2 GHz
# 2        Mediatek                Helio G85      Octa Core               2 GHz
# 3        Mediatek                Helio G85      Octa Core               2 GHz
# 4      Snapdragon  7 Gen 3 Mobile Platform      Octa Core            2.63 GHz
#
#   Secondary Clock Speed                                Operating Frequency  \
# 0               1.7 GHz  4G LTE: B1/B2/B3/B5/B7/B8/B20/B28/B38/B40/B41,...
# 1               1.8 GHz  2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LT...
# 2               1.8 GHz  2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LT...
# 3               1.8 GHz  2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LT...
# 4               2.4 GHz  5G: n1/n2/n3/n5/n7/n8/n20/n26/n28/n38/n40/n41/...
#
#   Internal Storage   RAM Expandable Storage Supported Memory Card Type  \
# 0           128 GB  4 GB               1 TB                    MicroSD
# 1           128 GB  4 GB               1 TB                        NaN
# 2           128 GB  4 GB               1 TB                        NaN
# 3           128 GB  4 GB               1 TB                        NaN
# 4           256 GB  8 GB                NaN                        NaN
#
#   Memory Card Slot Type Primary Camera Available        Primary Camera  \
# 0        Dedicated Slot                      Yes            50MP + 2MP
# 1                   NaN                      Yes      50MP Rear Camera
# 2                   NaN                      Yes      50MP Rear Camera
# 3        Dedicated Slot                      Yes  50MP + AI Lens + 2MP
# 4                   NaN                      Yes    50MP + 13MP + 10MP
#
#                              Primary Camera Features  \
# 0  Dual Camera Setup: 50MP Main Camera (f/1.8 Ape...
# 1  Triple AI Camera Setup: 50MP (f/1.8 Aperture, ...
# 2  Triple AI Camera Setup: 50MP (f/1.8 Aperture, ...
# 3  Triple AI Camera Setup: 50MP Main Camera (f/1....
# 4  Triple Camera Setup: 50MP Main Camera (1/1.3 i...
#
#   Secondary Camera Available   Secondary Camera  \
# 0                        Yes  16MP Front Camera
# 1                        Yes   8MP Front Camera
# 2                        Yes   8MP Front Camera
# 3                        Yes   8MP Front Camera
# 4                        Yes  50MP Front Camera
#
#                            Secondary Camera Features             Flash  \
# 0  Front Camera Setup: 16MP (f/2.4 Aperture, 1.0u...  Single LED Flash
# 1  Front Camera Setup: 8MP, Features: AI Portrait...        Rear Flash
# 2  Front Camera Setup: 8MP, Features: AI Portrait...        Rear Flash
# 3  8MP Front Camera Setup: Features: AI Portrait ...        Rear Flash
# 4  Front Camera Setup: 50MP Camera (f/1.9 Apertur...  Single LED Flash
#
#   HD Recording Full HD Recording Video Recording  \
# 0          Yes               Yes             Yes
# 1          Yes               Yes             Yes
# 2          Yes               Yes             Yes
# 3          Yes               Yes             Yes
# 4          Yes               Yes             Yes
#
#                           Video Recording Resolution Digital Zoom  \
# 0  Rear Camera: Main Camera (FHD (at 30 fps)), Ma...      Upto 4X
# 1  Rear Camera: 1080p (at 30 fps), 720p (at 30 fp...     Upto 10X
# 2  Rear Camera: 1080p (at 30 fps), 720p (at 30 fp...     Upto 10X
# 3  Rear Camera: 1080p (at 30 fps), 720p (at 30 fp...     Upto 10X
# 4  Rear Camera: Main Camera [4K UHD (at 30 fps), ...          NaN
#
#                          Frame Rate Dual Camera Lens Speaker Phone  \
# 0                            30 fps   Primary Camera           Yes
# 1                             90 Hz   Primary Camera           Yes
# 2                             90 Hz   Primary Camera           Yes
# 3                             90 Hz   Primary Camera           Yes
# 4  240 fps, 120 fps, 60 fps, 30 fps   Primary Camera           Yes
#
#            Network Type            Supported Networks  \
# 0            2G, 3G, 4G             4G LTE, GSM, UMTS
# 1  4G VOLTE, 4G, 3G, 2G  4G VoLTE, 4G LTE, WCDMA, GSM
# 2  4G VOLTE, 4G, 3G, 2G  4G VoLTE, 4G LTE, WCDMA, GSM
# 3  2G, 3G, 4G, 4G VOLTE  4G LTE, 4G VoLTE, GSM, WCDMA
# 4        2G, 3G, 4G, 5G         4G LTE, 5G, GSM, UMTS
#
#        Internet Connectivity   3G      Micro USB Version Bluetooth Support  \
# 0              4G, 3G, Wi-Fi  Yes  Type C Port (USB 2.0)               Yes
# 1  4G, 3G, Wi-Fi, EDGE, GPRS  Yes                 Type-C               Yes
# 2  4G, 3G, Wi-Fi, EDGE, GPRS  Yes                 Type-C               Yes
# 3  4G, 3G, Wi-Fi, EDGE, GPRS  Yes                 Type-C               Yes
# 4    5G, 4G, 3G, Edge, Wi-Fi  Yes  Type C Port (USB 3.1)               Yes
#
#   Bluetooth Version Wi-Fi                                      Wi-Fi Version  \
# 0              v5.2   Yes          Wi-Fi 802.11 a/b/g/n/ac (2.4 GHz | 5 GHz)
# 1              v5.3   Yes               Supports 2.4 GHz and 5 GHz Dual Band
# 2              v5.3   Yes               Supports 2.4 GHz and 5 GHz Dual Band
# 3              v5.3   Yes               Supports 2.4 GHz and 5 GHz Dual Band
# 4              v5.4   Yes  Wi-Fi 802.11 a/b/g/n/ac/ax (2.4 GHz | 5 GHz | ...
#
#   Wi-Fi Hotspot USB Connectivity Audio Jack GPS Support Smartphone  SIM Size  \
# 0           Yes              Yes      3.5mm         Yes        Yes  Nano Sim
# 1           Yes              Yes      3.5mm         Yes        Yes  Nano Sim
# 2           Yes              Yes      3.5mm         Yes        Yes  Nano Sim
# 3           Yes              Yes      3.5mm         Yes        Yes  Nano Sim
# 4           Yes              Yes        NaN         Yes        Yes       NaN
#
#    SMS                                            Sensors  \
# 0  Yes  Accelerometer, Proximity Sensor, Ambient Light...
# 1  Yes  Accelerometer, Side Fingerprint Sensor, Ambien...
# 2  Yes  Accelerometer, Side Fingerprint Sensor, Ambien...
# 3  Yes  Accelerometer, Side Fingerprint Sensor, Ambien...
# 4  Yes  Proximity Sensor, 3-in-1 Sensor (Exposure, Aut...
#
#            Upgradable Operating System  \
# 0           1 OS Upgrade, 3 Years SMRs
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4  3 Years OS Upgrade, 4 Years of SMRs
#
#                                       Other Features  \
# 0  4 GB RAM Boost, 30W Device Charging Capable, W...
# 1  MIUI Dialer, Support 18W Fast Charging, 4 GB T...
# 2  MIUI Dialer, Support 18W Fast Charging, 4 GB T...
# 3                                        MIUI Dialer
# 4  UFS 2.2, Display Certification: Amazon HD Stre...
#
#                                           GPS Type FM Radio  \
# 0        GPS, A-GPS, GLONASS, GALILEO, LTEPP, SUPL      Yes
# 1              GPS, AGPS, GLONASS, GALILEO, BEIDOU      Yes
# 2              GPS, AGPS, GLONASS, GALILEO, BEIDOU      Yes
# 3              GPS, AGPS, GLONASS, GALILEO, BEIDOU      Yes
# 4  GPS, AGPS, LTEPP, SUPL, GLONASS, GALILEO, NAVIC      NaN
#
#   FM Radio Recording Battery Capacity     Width     Height    Depth Weight  \
# 0                Yes         6000 mAh  74.53 mm  163.49 mm  8.99 mm  196 g
# 1                Yes         5000 mAh       NaN     168 mm  8.09 mm  192 g
# 2                Yes         5000 mAh       NaN     168 mm  8.09 mm  192 g
# 3                Yes         5000 mAh       NaN     168 mm  8.09 mm  192 g
# 4                NaN         4500 mAh   72.4 mm  161.23 mm  8.19 mm  186 g
#
#                                     Warranty Summary Domestic Warranty  \
# 0      1 Year on Handset and 6 Months on Accessories            1 Year
# 1  1 Year Manufacturer Warranty for Phone and 6 M...            1 Year
# 2  1 Year Manufacturer Warranty for Phone and 6 M...            1 Year
# 3  1 Year Manufacturer Warranty for Phone and 6 M...            1 Year
# 4      1 Year on Handset and 6 Months on Accessories            1 Year
#
#                                            SAR Value Call Log Memory  \
# 0                                                NaN             NaN
# 1  SAR Limit: 1.6 W/kg, Head: 0.809 W/kg, Body: 0...             Yes
# 2  SAR Limit: 1.6 W/kg, Head: 0.809 W/kg, Body: 0...             Yes
# 3  SAR Limit: 1.6 W/kg, Head SAR: 0.809 W/kg, Bod...             Yes
# 4   Head: 1.08 W/kg (at 1g), Body: 1.08 W/kg (at 1g)             NaN
#
#   Image Editor Call Wait/Hold Conference Call Hands Free Call Divert  \
# 0          NaN            NaN             NaN        NaN         NaN
# 1          Yes            Yes             Yes        Yes         Yes
# 2          Yes            Yes             Yes        Yes         Yes
# 3          Yes            Yes             Yes        Yes         Yes
# 4          NaN            NaN             NaN        NaN         NaN
#
#   Phone Book Call Timer Call Records GPRS Micro USB Port Mini HDMI Port  NFC  \
# 0        NaN        NaN          NaN  NaN            NaN            NaN  NaN
# 1        Yes        Yes          Yes  Yes            Yes             No   No
# 2        Yes        Yes          Yes  Yes            Yes             No   No
# 3        Yes        Yes          Yes  Yes            Yes             No   No
# 4        NaN        NaN          NaN  NaN            Yes            NaN  Yes
#
#   USB Tethering Infrared  Map Support Touchscreen Type  \
# 0           NaN      NaN          NaN              NaN
# 1           Yes       No  Google Maps       Capacitive
# 2           Yes       No  Google Maps       Capacitive
# 3           Yes       No  Google Maps       Capacitive
# 4           NaN      NaN          NaN              NaN
#
#                   User Interface Instant Message Removable Battery  MMS  \
# 0                            NaN             NaN               NaN  NaN
# 1  Android 13 (Based on MIUI 14)             Yes                No  Yes
# 2  Android 13 (Based on MIUI 14)             Yes                No  Yes
# 3  Android 13 (Based on MIUI 14)             Yes                No  Yes
# 4                            NaN             NaN               NaN  NaN
#
#   Keypad Voice Input Predictive Text Input        Browser Music Player  \
# 0    NaN         NaN                   NaN            NaN          NaN
# 1     No         Yes                   Yes  Google Chrome          Yes
# 2     No         Yes                   Yes  Google Chrome          Yes
# 3     No         Yes                   Yes  Google Chrome          Yes
# 4    NaN         NaN                   NaN            NaN          NaN
#
#       Battery Type Warranty Service Type Total Memory EDGE User Memory  \
# 0              NaN                   NaN          NaN  NaN         NaN
# 1  Lithium Polymer                    NA          NaN  NaN         NaN
# 2  Lithium Polymer                    NA          NaN  NaN         NaN
# 3  Lithium Polymer                    NA       128 GB  Yes      103.58
# 4              NaN                   NaN          NaN  Yes         NaN
#
#   Additional Content Tertiary Clock Speed Optical Zoom Graphics PPI  \
# 0                NaN                  NaN          NaN          NaN
# 1                NaN                  NaN          NaN          NaN
# 2                NaN                  NaN          NaN          NaN
# 3                NaN                  NaN          NaN          NaN
# 4   with 68W Charger              1.8 GHz          Yes      446 PPI
#
#   HD Game Support Display Colors Video Call Support Speed Dialing Logs  \
# 0             NaN            NaN                NaN           NaN  NaN
# 1             NaN            NaN                NaN           NaN  NaN
# 2             NaN            NaN                NaN           NaN  NaN
# 3             NaN            NaN                NaN           NaN  NaN
# 4             NaN            NaN                NaN           NaN  NaN
#
#   3G Speed Pre-installed Browser Mini USB Port Social Networking Phone  \
# 0      NaN                   NaN           NaN                     NaN
# 1      NaN                   NaN           NaN                     NaN
# 2      NaN                   NaN           NaN                     NaN
# 3      NaN                   NaN           NaN                     NaN
# 4      NaN                   NaN           NaN                     NaN
#
#   Business Phone SIM Access Series Ringtones Format DLNA Support  \
# 0            NaN        NaN    NaN              NaN          NaN
# 1            NaN        NaN    NaN              NaN          NaN
# 2            NaN        NaN    NaN              NaN          NaN
# 3            NaN        NaN    NaN              NaN          NaN
# 4            NaN        NaN    NaN              NaN          NaN
#
#   Audio Formats Video Formats Dual Battery Covered in Warranty  \
# 0           NaN           NaN          NaN                 NaN
# 1           NaN           NaN          NaN                 NaN
# 2           NaN           NaN          NaN                 NaN
# 3           NaN           NaN          NaN                 NaN
# 4           NaN           NaN          NaN                 NaN
#
#   Supported Languages Important Apps TV Out Mobile Tracker Talk Time  \
# 0                 NaN            NaN    NaN            NaN       NaN
# 1                 NaN            NaN    NaN            NaN       NaN
# 2                 NaN            NaN    NaN            NaN       NaN
# 3                 NaN            NaN    NaN            NaN       NaN
# 4                 NaN            NaN    NaN            NaN       NaN
#
#   Not Covered in Warranty Phone Book Memory Java Application JAVA Support  \
# 0                     NaN               NaN              NaN          NaN
# 1                     NaN               NaN              NaN          NaN
# 2                     NaN               NaN              NaN          NaN
# 3                     NaN               NaN              NaN          NaN
# 4                     NaN               NaN              NaN          NaN
#
#   Keypad Type SMS Memory Games
# 0         NaN        NaN   NaN
# 1         NaN        NaN   NaN
# 2         NaN        NaN   NaN
# 3         NaN        NaN   NaN
# 4         NaN        NaN   NaN
